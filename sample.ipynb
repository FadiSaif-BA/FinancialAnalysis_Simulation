# %%
from src.visualizations import FinancialVisualizer
from src.predictive_analytics import PredictiveAnalyzer

viz = FinancialVisualizer()

# Trend chart with bars + line
viz.plot_trend_with_bars(trend_data, save_path='reports/trend_chart.png')

# Combined forecast chart
viz.plot_forecast_combined(forecast_data, save_path='reports/forecast_chart.png')

# Full dashboard
viz.plot_predictive_dashboard(trend_data, forecast_data, at_risk_clients,
                               save_path='reports/predictive_dashboard.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 viz = FinancialVisualizer()
#       6 # Trend chart with bars + line
# ----> 7 viz.plot_trend_with_bars(trend_data, save_path='reports/trend_chart.png')
#       9 # Combined forecast chart
#      10 viz.plot_forecast_combined(forecast_data, save_path='reports/forecast_chart.png')
#
# NameError: name 'trend_data' is not defined
